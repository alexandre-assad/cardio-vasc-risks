# %%
from scripts.generic_methods import load_dataset
from icecream import ic

DATASET = load_dataset("../data/filtered/analysis.csv", ",")

# %%
DATASET.head()
# Out:
#    Unnamed: 0  cardio  is_overweight  bmi_is_valid  is_healthy  ap_lo  years  \
# 0           0   False          False          True        True   80.0     50
# 1           1    True           True          True       False   90.0     55
# 2           2    True          False          True       False   70.0     51
# 3           3   False          False          True        True   60.0     47
# 4           4   False           True          True       False   80.0     60
#
#      bmi  height_is_valid   alco  ...          ap_hi_status          gluc  \
# 0  21.97             True  False  ...                NORMAL        NORMAL
# 1  34.93             True  False  ...  HYPERTENSION_STAGE_2        NORMAL
# 2  23.51             True  False  ...  HYPERTENSION_STAGE_1        NORMAL
# 3  23.01             True  False  ...                NORMAL        NORMAL
# 4  29.38             True  False  ...                NORMAL  ABOVE_NORMAL
#
# ...

# %%
DATASET.columns
# Out:
# Index(['Unnamed: 0', 'cardio', 'is_overweight', 'bmi_is_valid', 'is_healthy',
#        'ap_lo', 'years', 'bmi', 'height_is_valid', 'alco', 'active', 'sex',
#        'id', 'bmi_status', 'broader_age_group', 'ap_lo_status', 'age', 'smoke',
#        'is_underweight', 'height', 'in_hypertension', 'ap_hi_status', 'gluc',
#        'is_valid', 'age_is_valid', 'weight_is_valid', 'weight', 'age_group',
#        'ap_hi', 'gender', 'cholesterol'],
#       dtype='object')

# %%
CATEGORICAL_FIELDS = ["ap_hi_status", "ap_lo_status", "cholesterol", "gluc"]

# %%
import matplotlib.pyplot as plt

DATASET.groupby(['ap_hi_status', 'cardio']).size().unstack().plot(kind='bar')
plt.xlabel('ap_hi_status')
plt.ylabel('Count')
plt.title('Number of Sick and Non-Sick Patients by ap_hi_status')

plt.xticks(rotation=45)  # Rotate x-axis labels by 45 degrees

plt.show()
